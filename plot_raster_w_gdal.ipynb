# %% [markdown]
# Made with the help of http://ceholden.github.io/open-geo-tutorial/python/chapter_3_visualization.html

# %%
from osgeo import gdal
from osgeo import gdal_array
from constants import *
import numpy as np
import matplotlib.pyplot as plt
from scripts.gdal_scripts import *

# %%
main_name = "output"
dataset = gdal_open_tif(tif_name=main_name)

# %%
gdal_print_metadata(tif_name=main_name)
# Out:
# Driver: GTiff/GeoTIFF
# Files: tif_files/output.tif
# Size is 256, 256
# Coordinate System is:
# GEOGCRS["WGS 84",
#     DATUM["World Geodetic System 1984",
#         ELLIPSOID["WGS 84",6378137,298.257223563,
#             LENGTHUNIT["metre",1]]],
#     PRIMEM["Greenwich",0,
#         ANGLEUNIT["degree",0.0174532925199433]],
#     CS[ellipsoidal,2],
#         AXIS["geodetic latitude (Lat)",north,
#             ORDER[1],
#             ANGLEUNIT["degree",0.0174532925199433]],
#         AXIS["geodetic longitude (Lon)",east,
#             ORDER[2],
#             ANGLEUNIT["degree",0.0174532925199433]],
#     ID["EPSG",4326]]
# Data axis to CRS axis mapping: 2,1
# Origin = (8.943549000000001,56.943096810000000)
# Pixel Size = (0.000455029121094,0.000210332773437)
# Metadata:
#   AREA_OR_POINT=Area
# Image Structure Metadata:
#   INTERLEAVE=BAND
# Corner Coordinates:
# Upper Left  (   8.9435490,  56.9430968) (  8d56'36.78"E, 56d56'35.15"N)
# ...

# %%
plot_raster(tif_name=main_name)
