# %%
from constants import *
import pandas as pd
from scripts.scripts import *

# %%
main_name = "test_grid02"
df = get_pandas_from_csv(csv_name=main_name)
df = df.rename(columns={'Unnamed: 0':'lat'})
df
# Out:
#           lat  9.065843041  9.065923535  9.066007064  9.066084523  \
# 0   56.835195          100          100          100          100
# 1   56.835185          100          100          100          100
# 2   56.835176           80           80          100          100
# 3   56.835167           80           80          100          100
# 4   56.835158           80           80          100          100
# 5   56.835149           80           80          100          100
# 6   56.835139          100          100          100          100
# 7   56.835130          100          100          100          100
# 8   56.835121          100          100          100          100
# 9   56.835112          100          100          100          100
# 10  56.835103          100          100          100          100
# 11  56.835094           60           60          100          100
# 12  56.835084           60           60          100          100
# ...

# %%
plt.imshow(df, aspect='auto')
plt.colorbar()

# %%
df = grid_to_coordinate(grid_df=df,target_column="value")

# %%
df
# Out:
#            lat          lon  value
# 0    56.835195  9.065843041    100
# 1    56.835185  9.065843041    100
# 2    56.835176  9.065843041     80
# 3    56.835167  9.065843041     80
# 4    56.835158  9.065843041     80
# ..         ...          ...    ...
# 425  56.834846  9.066567485      0
# 426  56.834836  9.066567485      0
# 427  56.834827  9.066567485      0
# 428  56.834818  9.066567485      0
# 429  56.834809  9.066567485      0
#
# [430 rows x 3 columns]

# %%
pandas_to_csv(df=df,csv_name=main_name+"_coor")

# %%
dataframe_to_shp(
    input_df=df,
    output_file_path=main_name
    )
# Out:
#            lat          lon  value                  geometry
# 0    56.835195  9.065843041    100  POINT (9.06584 56.83519)
# 1    56.835185  9.065843041    100  POINT (9.06584 56.83519)
# 2    56.835176  9.065843041     80  POINT (9.06584 56.83518)
# 3    56.835167  9.065843041     80  POINT (9.06584 56.83517)
# 4    56.835158  9.065843041     80  POINT (9.06584 56.83516)
# ..         ...          ...    ...                       ...
# 425  56.834846  9.066567485      0  POINT (9.06657 56.83485)
# 426  56.834836  9.066567485      0  POINT (9.06657 56.83484)
# 427  56.834827  9.066567485      0  POINT (9.06657 56.83483)
# 428  56.834818  9.066567485      0  POINT (9.06657 56.83482)
# 429  56.834809  9.066567485      0  POINT (9.06657 56.83481)
#
# [430 rows x 4 columns]
